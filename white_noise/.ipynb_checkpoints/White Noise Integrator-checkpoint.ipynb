# %% [markdown]
# Based on the google-research/computation-thru-dynamics github repo's integrator RNN tutorial

# %% [markdown]
# Import Dependencies

# %%
WORKING_DIR = '/Users/mohammed/Desktop/Bio-X/goal-driven-ANNs'
import sys
sys.path.append(WORKING_DIR)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from models.VRNN import VRNN

# %% [markdown]
# Hyperparameters

# %%
T = 1.0
SEQUENCE_LEN = 25
FEATURE_DIM = 1
HIDDEN_DIM = 64
BATCH_SIZE = 50
NUM_BATCHES = 1000 # 10000
PRINT_EVERY = NUM_BATCHES // 10
LEARNING_RATE = 1e-4

# %% [markdown]
# Helper Methods

# %%
def generate_noise(batch_size, time, num_time_steps, bias_val=.01, stddev_val=0.025):
    dt = time / num_time_steps
    bias = bias_val * 2.0 * (np.random.randn() - 0.5)
    stddev = stddev_val / np.sqrt(dt)
    X = bias + stddev * np.random.randn(batch_size, num_time_steps, 1)
    y = np.cumsum(X, axis=1)
    return torch.from_numpy(X).float(), torch.from_numpy(y).float()

def plot_sequence(seq1, seq2):
    seq1 = seq1.detach()
    seq2 = seq2.detach()
    n, T, d = seq1.shape
    if d > 1:
        print("Cannot plot multi-dimensional data")
  
    max_value = max(np.abs(seq1).max(), np.abs(seq2).max()) + 1
    cmap = plt.get_cmap(name='hsv', lut=n)
    plt.axhline(y=0, color='black', linestyle='-', alpha=.8)
    for i in range(n):
        plt.plot(seq1[i, :, 0], color=cmap(i), alpha=.8)
        plt.plot(seq2[i, :, 0], color=cmap(i), alpha=.8, linestyle='dashed')
    plt.xlabel('time step')
    plt.ylabel('position')
    plt.axis([0, T - 1, -1 * max_value, max_value])
    plt.show()
  
def print_loss(loss, batch):
    scalar = float(loss)
    print('{}. loss = {}'.format(batch, scalar))

# %%
X, y = generate_noise(10, T, SEQUENCE_LEN)
plot_sequence(X, y)

# %% [markdown]
# Train Model

# %%
net = VRNN(FEATURE_DIM, HIDDEN_DIM)
optimizer = torch.optim.RMSprop(net.parameters(), lr=LEARNING_RATE)
criterion = torch.nn.MSELoss()

for i in range(NUM_BATCHES):
    input, target = generate_noise(BATCH_SIZE, T, SEQUENCE_LEN)
    optimizer.zero_grad()
    output, neurons = net(input)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    if i % PRINT_EVERY == 0:
        print_loss(loss, i)
# Out:
# 0. loss = 0.4330694377422333
# 100. loss = 0.036382775753736496
# 200. loss = 0.020785680040717125
# 300. loss = 0.009624915197491646
# 400. loss = 0.005059911869466305
# 500. loss = 0.005681384354829788
# 600. loss = 0.0026204900350421667
# 700. loss = 0.002923323307186365
# 800. loss = 0.005266933236271143
# 900. loss = 0.004207640420645475

# %% [markdown]
# Test Model

# %%
input, target = generate_noise(10, T, SEQUENCE_LEN)
untrained = VRNN(FEATURE_DIM, HIDDEN_DIM)
naive_pred, _ = untrained(input)
plot_sequence(target, naive_pred)
pred, _ = net(input)
plot_sequence(target, pred)
