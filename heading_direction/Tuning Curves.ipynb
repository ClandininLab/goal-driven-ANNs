# %%
import numpy as np
import matplotlib.pyplot as plt

import os
import sys
parent_directory = os.path.dirname(os.getcwd())
sys.path.append(parent_directory)
from util import visualize_recurrent

from tuning_curves import sort_units_by_peaks, plot_tuning

# %%
hidden_dim = 100
experiment_name = str(hidden_dim)
load_format = (experiment_name, experiment_name)

weights = np.load('%s/W_%s.npy' % load_format)
tuning, _ = np.load('%s/tuning_%s.npy' % load_format)
num_bins = tuning.shape[-1]

# %%
(W_trained, W_untrained), tuning, peaks = sort_units_by_peaks(weights, tuning)

# %%
visualize_recurrent(W_untrained)
visualize_recurrent(W_trained)

# %%
plt.hist(peaks, bins=range(num_bins + 1))
plt.show()

# %%
plot_tuning(tuning)
